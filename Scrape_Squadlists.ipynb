# %% [markdown]
# ## Soccerway squad lists scraper
#
# The website soccerway.com is sits on top of an almost endless database of football matches from all points of the globe. As someone who reports on football, and also a football fan, it's one of my go-to sources for information.
#
# This is one of many scripts I have written over to collect information from the site, which then makes the data infinitely more accessible for carrying out data analytics.
#
# This script focusses on getting the basic player line-ups from a match: the home team, the away team and their substitutes. It includes other basic and important data such as the minutes played and whether the player was on the home or away team.
#
# An exhaustive assmebler of data from a match it is not, but as a tool for seeing who played when, it proved incredibly helpful as I investigated the recruitment of Brazilians for the national side of Timor-Leste in mid 2010s, a story I broke for the New York Times.

# %%
A script to scrape player line-ups and additional basic information (such as minutes played and opponent) for matches listed on the Soccerway website.

# %%
from requests import get
from bs4 import BeautifulSoup
import json
import pandas as pd
import re

# %%
def getPlayersInGame(url):
    
    dfGAMELINEUP = pd.DataFrame(columns=['Date', 'Team', 'Opponent', 'HA', 'Player', 'Minutes', 'Player Link'])
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
        
    match = soup.title.text
    teams = match.split(' - ')[0]
    homeTeam, awayTeam = teams.split(' vs. ')
    date = match.split(' - ')[1]
 
    def getDataFromCombinedLineupsContainers(n, N):
                
        ha = 'H' if N == 0 else 'A'
        
        cLC = combinedLineupsContainers[n].find_all('tbody')[N]
            
        for tr in cLC.find_all('tr'):

            for player in tr.find_all('td', {'class':'player'}):
                
                playerMinutes = None
                
                playerLink = player.find('a')['href']        
                playerName = player.text.replace('\n','')
                
                playerTeam = homeTeam if N == 0 else awayTeam
                opponentTeam = homeTeam if N == 1 else awayTeam
                
                ###### Starting lineup #######
                if n == 0:   
                
                    subbed = player.find('img')
                    if subbed == None:
                            playerMinutes = 90
                            
                    else:
                            playerMinutes = 'TBC'
                                                
                ###### Subs ##################
                
                if n == 1:   
                                        
                    subbed = player.find('img', {'alt': 'Substituted'})
                    
                    if subbed != None:   # This section calculates the minutes played for the players subbed on and off 
                        
                        subIN = player.find('p', {'class': 'substitute-in'}).text.strip()
                        
                        subOUTALL = player.find('p', {'class': 'substitute-out'}).text.replace('for ','').strip()
                        subOUTALL = re.split("([0-9]{1,3}\')", subOUTALL)
                        subOUT = subOUTALL[0].strip()
                        
                        subTIME = int(subOUTALL[1].replace("'",""))                        
                        subINMINS = 90 - subTIME
                        
                        playerName = subIN
                        playerMinutes = subINMINS
                        
                        dfGAMELINEUP.loc[dfGAMELINEUP['Player'] == subOUT, 'Minutes'] = subTIME
                        
                    else:   # Players left on the bench get zero minutes
                        
                        playerMinutes = 0
                        
                dfGAMELINEUP.loc[dfGAMELINEUP.shape[0]] = [date, playerTeam, opponentTeam, ha, playerName, playerMinutes, playerLink]

    # This section runs the above function four times: for the home side's starting line-up, for their subs, and for the away team's starters and subs
    combinedLineupsContainers = soup.find_all('div', {'class':'combined-lineups-container'})
    for n in range(0, len(combinedLineupsContainers)):
        haCombinedLineupsContainers = combinedLineupsContainers[n].find_all('tbody')
        for N in range(0, len(haCombinedLineupsContainers)):
            getDataFromCombinedLineupsContainers(n, N)
            
    dfGAMELINEUP = dfGAMELINEUP.sort_values(by=['HA', 'Minutes', 'Player'], ascending=[False, False, True])

    return dfGAMELINEUP

# %%
dfALL = pd.DataFrame()

urls = ['https://int.soccerway.com/matches/2015/10/08/asia/wc-qualifying-asia/timor-leste/palestine/2028605/',
       ]

for url in urls:
    
    dfX = getPlayersInGame(url)
    
    dfALL = pd.concat([dfALL, dfX], ignore_index=True)

dfALL
# Out:
#               Date         Team     Opponent HA                 Player  \
# 0   8 October 2015  Timor-Leste    Palestine  H                    Ade
# 1   8 October 2015  Timor-Leste    Palestine  H           Diogo Rangel
# 2   8 October 2015  Timor-Leste    Palestine  H                 Filipe
# 3   8 October 2015  Timor-Leste    Palestine  H                 Helber
# 4   8 October 2015  Timor-Leste    Palestine  H           Jose Fonseca
# 5   8 October 2015  Timor-Leste    Palestine  H                Juninho
# 6   8 October 2015  Timor-Leste    Palestine  H          Patrick Alves
# 7   8 October 2015  Timor-Leste    Palestine  H                  Ramon
# 8   8 October 2015  Timor-Leste    Palestine  H                  Ramos
# 9   8 October 2015  Timor-Leste    Palestine  H            Rodriguinho
# 10  8 October 2015  Timor-Leste    Palestine  H                  Magno
# 11  8 October 2015  Timor-Leste    Palestine  H             Jairo Neto
# 12  8 October 2015  Timor-Leste    Palestine  H                Adérito
# 13  8 October 2015  Timor-Leste    Palestine  H              Agostinho
# 14  8 October 2015  Timor-Leste    Palestine  H                 Carlos
# 15  8 October 2015  Timor-Leste    Palestine  H               Chiquito
# 16  8 October 2015  Timor-Leste    Palestine  H              Goncalves
# 17  8 October 2015  Timor-Leste    Palestine  H               Henrique
# 18  8 October 2015  Timor-Leste    Palestine  H                 Juliao
# 19  8 October 2015  Timor-Leste    Palestine  H               Nataniel
# 20  8 October 2015  Timor-Leste    Palestine  H                  Nidio
# 21  8 October 2015  Timor-Leste    Palestine  H                   Nilo
# 22  8 October 2015    Palestine  Timor-Leste  A         Abdallah Jaber
# 23  8 October 2015    Palestine  Timor-Leste  A  Abdallatif Al-Bahdari
# 24  8 October 2015    Palestine  Timor-Leste  A            Imad Zatara
# 25  8 October 2015    Palestine  Timor-Leste  A         Khader Youssef
# 26  8 October 2015    Palestine  Timor-Leste  A       Mus'ab Al-Battat
# 27  8 October 2015    Palestine  Timor-Leste  A          Sameh Maraaba
# 28  8 October 2015    Palestine  Timor-Leste  A            Tamer Salah
# 29  8 October 2015    Palestine  Timor-Leste  A             Tawfiq Ali
# 30  8 October 2015    Palestine  Timor-Leste  A            Mahmoud Eid
# 31  8 October 2015    Palestine  Timor-Leste  A          Mahmoud Salah
# 32  8 October 2015    Palestine  Timor-Leste  A            Tamer Seyam
# 33  8 October 2015    Palestine  Timor-Leste  A           Matías Jadue
# 34  8 October 2015    Palestine  Timor-Leste  A    Jonathan Cantillana
# 35  8 October 2015    Palestine  Timor-Leste  A            Ahmed Nayea
# 36  8 October 2015    Palestine  Timor-Leste  A        Abdallah Idrees
# 37  8 October 2015    Palestine  Timor-Leste  A           Ahmad Shebel
# 38  8 October 2015    Palestine  Timor-Leste  A          Belal Al Sabe
# 39  8 October 2015    Palestine  Timor-Leste  A             Eyad Slbes
# 40  8 October 2015    Palestine  Timor-Leste  A        Ghanem Mahajneh
# 41  8 October 2015    Palestine  Timor-Leste  A         Jaka Ihbeisheh
# 42  8 October 2015    Palestine  Timor-Leste  A         Mahmoud Dawoud
# 43  8 October 2015    Palestine  Timor-Leste  A     Mohammed Abukhamis
# 44  8 October 2015    Palestine  Timor-Leste  A        Mohammed Yameen
#
#    Minutes                                        Player Link
# 0       90  /players/adelino-trindade-coelho-manek-de-oliv...
# 1       90               /players/diogo-santos-rangel/271101/
# 2       90                   /players/filipe-oliveira/373267/
# 3       90         /players/paulo-helber-rosa-ribeiro/271110/
# 4       90            /players/jose-carlos-da-fonseca/399495/
# 5       90  /players/junior-aparecido-guimaro-de-souza/178...
# 6       90      /players/patrick-fabiano-alves-nobrega/71367/
# 7       90                /players/ramon-de-lima-saro/271108/
# 8       90  /players/ramos-saozinho-ribeiro-maxanches/271097/
# 9       90               /players/rodrigo-souza-silva/110171/
# 10      62  /players/carlos-jovanio-celesti-de-araujo-magn...
# 11      28      /players/jairo-pinheiro-palmeira-neto/399491/
# 12       0            /players/aderito-raul-fernandes/424951/
# 13       0         /players/agostinho-araujo-da-silva/373259/
# 14       0             /players/carlos-mateus-ximenes/165554/
# 15       0                 /players/chiquito-do-carmo/161779/
# 16       0               /players/feliciano-goncalves/384771/
# 17       0  /players/henrique-wilsons-da-cruz-martins/399490/
# 18       0                   /players/juliao-monteiro/271095/
# 19       0            /players/nataniel-de-jesus-reis/373271/
# 20       0      /players/nidio-octavio-das-dores-neto/399499/
# 21       0  /players/nicolau-higinio-baptista-soares-ferna...
# 22      90                    /players/abdallah-gaber/243482/
# 23      90         /players/abdallatif-m-s-al-bahdari/120419/
# 24      90                        /players/imad-zatara/33726/
# 25      90              /players/khader-y-a-abuhammad/120424/
# 26      90                   /players/musab-al-battat/293049/
# 27      90                     /players/sameh-maraaba/190347/
# 28      90                       /players/tamer-salah/315698/
# 29      90                  /players/tawfiq-abuhammad/165277/
# 30      80                       /players/mahmoud-eid/186693/
# 31      62               /players/mahmoud-shaikhqasem/243349/
# 32      53                       /players/tamer-seyam/342707/
# 33      37                      /players/matias-jadue/136830/
# 34      28               /players/jonathan-cantillana/288284/
# 35      10                       /players/ahmed-nayea/204530/
# 36       0                   /players/abdallah-idrees/396260/
# 37       0                        /players/ahmad-sbil/176623/
# 38       0                      /players/belal-alsabe/425106/
# 39       0                        /players/slbes-eyad/242092/
# 40       0                   /players/ghanem-mahajneh/325625/
# 41       0                    /players/jaka-ihbeisheh/135916/
# 42       0                    /players/mahmoud-dawoud/190341/
# 43       0                /players/mohammed-abukhamis/397341/
# 44       0                   /players/mohammed-yameen/406997/
